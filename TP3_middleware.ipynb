# %%
import sys
import requests
import json

def handleResponse(r):
    print (r.status_code)
    print (r.headers)
    print (r.text)
    return;

def createAE():
    payload = '{ \
    "m2m:ae": { \
        "rn": "AE1", \
        "api": "NAE1", \
        "rr": true, \
        "srv": ["3"] \
        } \
        }'
    
    _headers = {
    "X-M2M-Origin": "Cmyself2",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=2",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.post("http://127.0.0.1:8080/cse-in",data=payload,headers=_headers)
    handleResponse(r)

def createCIN():
    payload = '{ \
    "m2m:cin": { \
        "cnf": "text/plain:0", \
        "con": "helllo" \
    } \
    }'
    

    _headers = {
    "X-M2M-Origin": "Cmyself2",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=4",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.post("http://127.0.0.1:8080/cse-in/AE1/Container",data=payload,headers=_headers)
    handleResponse(r)
    
def createContainer():
    payload = '{ \
    "m2m:cnt": { \
        "rn": "Container" \
    } \
    }'

    _headers = {
    "X-M2M-Origin": "Cmyself2",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=3",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.post("http://127.0.0.1:8080/cse-in/AE1",data=payload,headers=_headers)
    handleResponse(r)

createAE()
createContainer()
createCIN()
# Out:
# 201
# {'Server': 'Werkzeug/2.2.2 Python/3.9.12, ACME 0.11.0', 'Date': 'Mon, 09 Jan 2023 17:57:13 GMT', 'X-M2M-RSC': '2001', 'X-M2M-RI': '123', 'X-M2M-RVI': '3', 'X-M2M-OT': '20230109T175713,237475', 'Content-Type': 'application/json', 'Content-Length': '223', 'Connection': 'close'}
# {"m2m:ae": {"rn": "AE1", "api": "NAE1", "rr": true, "srv": ["3"], "ri": "Cmyself2", "pi": "id-in", "ct": "20230109T175713,207855", "lt": "20230109T175713,207855", "et": "20280108T175713,207906", "ty": 2, "aei": "Cmyself2"}}
# 201
# {'Server': 'Werkzeug/2.2.2 Python/3.9.12, ACME 0.11.0', 'Date': 'Mon, 09 Jan 2023 17:57:13 GMT', 'X-M2M-RSC': '2001', 'X-M2M-RI': '123', 'X-M2M-RVI': '3', 'X-M2M-OT': '20230109T175713,340844', 'Content-Type': 'application/json', 'Content-Length': '214', 'Connection': 'close'}
# ...

# %%
import sys
import requests
import json

def handleResponse(r):
    print (r.status_code)
    print (r.headers)
    print (r.text)
    return;

def createAE1():
    payload = '{ \
    "m2m:ae": { \
        "rn": "AE1", \
        "api": "NAE1", \
        "rr": true, \
        "srv": ["3"] \
        } \
        }'
    
    _headers = {
    "X-M2M-Origin": "Cmyself1",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=2",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.post("http://127.0.0.1:8080/cse-in",data=payload,headers=_headers)
    handleResponse(r)

def createAE2():
    payload = '{ \
    "m2m:ae": { \
        "rn": "AE2", \
        "api": "NAE2", \
        "rr": true, \
        "srv": ["3"] \
        } \
        }'
    
    _headers = {
    "X-M2M-Origin": "Cmyself2",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=2",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.post("http://127.0.0.1:8080/cse-in",data=payload,headers=_headers)
    handleResponse(r)
    
def createLampe():
    payload = '{ \
    "m2m:cnt": { \
        "rn": "Lampe" \
    } \
    }'

    _headers = {
    "X-M2M-Origin": "Cmyself1",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=3",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.post("http://127.0.0.1:8080/cse-in/AE1",data=payload,headers=_headers)
    handleResponse(r)
    
def createBouton():
    payload = '{ \
    "m2m:cnt": { \
        "rn": "Bouton" \
    } \
    }'

    _headers = {
    "X-M2M-Origin": "Cmyself2",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=3",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.post("http://127.0.0.1:8080/cse-in/AE2",data=payload,headers=_headers)
    handleResponse(r)
    
def subserveur2():
    payload = '{ \
    "m2m:sub": { \
        "rn": "Subscription", \
        "nu": ["http://localhost:9999"], \
        "nct": 1, \
        "enc": { \
            "net": [ 1, 2, 3, 4 ] \
    } \
    } \
    }'

    _headers = {
    "X-M2M-Origin": "Cmyself2",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=23",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.post("http://127.0.0.1:8080/cse-in/AE2/Bouton",data=payload,headers=_headers)
    handleResponse(r)
    
def subserveur1():
    payload = '{ \
    "m2m:sub": { \
        "rn": "Subscription", \
        "nu": ["http://localhost:9999"], \
        "nct": 1, \
        "enc": { \
            "net": [ 1, 2, 3, 4 ] \
    } \
    } \
    }'

    _headers = {
    "X-M2M-Origin": "Cmyself1",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=23",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.post("http://127.0.0.1:8080/cse-in/AE1/Lampe",data=payload,headers=_headers)
    handleResponse(r)
    
def createCINLampe():
    payload = '{ \
    "m2m:cin": { \
        "rn": "CIN1", \
        "cnf": "text/plain:0", \
        "con": "0" \
    } \
    }'
    

    _headers = {
    "X-M2M-Origin": "Cmyself1",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=4",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.post("http://127.0.0.1:8080/cse-in/AE1/Lampe",data=payload,headers=_headers)
    handleResponse(r)
    
def createCINBouton():
    payload = '{ \
    "m2m:cin": { \
        "rn": "CIN2", \
        "cnf": "text/plain:0", \
        "con": "0" \
    } \
    }'
    

    _headers = {
    "X-M2M-Origin": "Cmyself2",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=4",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.post("http://127.0.0.1:8080/cse-in/AE2/Bouton",data=payload,headers=_headers)
    handleResponse(r)
    print(r.text)
    
createAE1()
createAE2()
createLampe()
createBouton()
createCINBouton()
createCINLampe()
#subserveur1()
#subserveur2()
# Out:
# 201
# {'Server': 'Werkzeug/2.2.2 Python/3.9.12, ACME 0.10.2', 'Date': 'Wed, 18 Jan 2023 07:59:51 GMT', 'X-M2M-RSC': '2001', 'X-M2M-RI': '123', 'X-M2M-RVI': '3', 'X-M2M-OT': '20230118T075951,722003', 'Content-Type': 'application/json', 'Content-Length': '223', 'Connection': 'close'}
# {"m2m:ae": {"rn": "AE1", "api": "NAE1", "rr": true, "srv": ["3"], "ri": "Cmyself1", "pi": "id-in", "ct": "20230118T075951,714510", "lt": "20230118T075951,714510", "et": "20240118T075951,714596", "ty": 2, "aei": "Cmyself1"}}
# 201
# {'Server': 'Werkzeug/2.2.2 Python/3.9.12, ACME 0.10.2', 'Date': 'Wed, 18 Jan 2023 07:59:51 GMT', 'X-M2M-RSC': '2001', 'X-M2M-RI': '123', 'X-M2M-RVI': '3', 'X-M2M-OT': '20230118T075951,734366', 'Content-Type': 'application/json', 'Content-Length': '223', 'Connection': 'close'}
# ...

# %%
def updateCINBouton():
    payload = '{ \
    "m2m:cin": { \
        "rn": "CIN", \
        "con": "1" \
    } \
    }'
    

    _headers = {
    "X-M2M-Origin": "Cmyself2",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=4",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.put("http://127.0.0.1:8080/cse-in/AE2/Bouton/CIN2",data=payload,headers=_headers)
    handleResponse(r)
    
updateCINBouton()
# Out:
# 405
# {'Server': 'Werkzeug/2.2.2 Python/3.9.12, ACME 0.10.2', 'Date': 'Mon, 16 Jan 2023 09:41:48 GMT', 'X-M2M-RSC': '4005', 'X-M2M-RI': '123', 'X-M2M-RVI': '3', 'X-M2M-OT': '20230116T094148,582337', 'Content-Type': 'application/json', 'Content-Length': '36', 'Connection': 'close'}
# {"m2m:dbg": "resource is read-only"}

# %%
import json
import requests
import time

def RetrieveBouton():
    payload = '{}'
    

    _headers = {
    "X-M2M-Origin": "Cmyself2",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=4",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.get("http://127.0.0.1:8080/cse-in/AE2/Bouton/CIN2",data=payload,headers=_headers)
    handleResponse(r)
    return r.text
    
def updateCINLampeON():
    payload = '{ \
    "m2m:cin": { \
        "con": "1" \
    } \
    }'
    _headers = {
    "X-M2M-Origin": "Cmyself2",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=4",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.put("http://127.0.0.1:8080/cse-in/AE1/Lampe/CIN1",data=payload,headers=_headers)
    handleResponse(r)
    
def updateCINLampeOFF():
    payload = '{ \
    "m2m:cin": { \
        "con": "0" \
    } \
    }'
    _headers = {
    "X-M2M-Origin": "Cmyself2",
    "X-M2M-RI": "123",
    "X-M2M-RVI":"3",
    "Content-Type":"application/json;ty=4",
    "Accept":"application/json"
    }
    json.dumps(json.loads(payload,strict=False), indent=4)
    r = requests.put("http://127.0.0.1:8080/cse-in/AE1/Lampe/CIN1",data=payload,headers=_headers)
    handleResponse(r)

while 1:
    rep=RetrieveBouton()
    val=rep[58]
    if val==0 :
        updateCINLampeOFF()
    elif val==1 :
        updateCINLampeON()
    time.sleep(5)
# Out:
# 200
# {'Server': 'Werkzeug/2.2.2 Python/3.9.12, ACME 0.10.2', 'Date': 'Mon, 16 Jan 2023 16:23:58 GMT', 'X-M2M-RSC': '2000', 'X-M2M-RI': '123', 'X-M2M-RVI': '3', 'X-M2M-OT': '20230116T162358,612195', 'Content-Type': 'application/json', 'Content-Length': '248', 'Connection': 'close'}
# {"m2m:cin": {"rn": "CIN2", "cnf": "text/plain:0", "con": "0", "ri": "cin651954189796801160", "pi": "cnt8760624019283138531", "ct": "20230116T162344,913463", "lt": "20230116T162344,913463", "et": "20240116T162344,913530", "ty": 4, "cs": 1, "st": 1}}
# 200
# {'Server': 'Werkzeug/2.2.2 Python/3.9.12, ACME 0.10.2', 'Date': 'Mon, 16 Jan 2023 16:24:03 GMT', 'X-M2M-RSC': '2000', 'X-M2M-RI': '123', 'X-M2M-RVI': '3', 'X-M2M-OT': '20230116T162403,666182', 'Content-Type': 'application/json', 'Content-Length': '248', 'Connection': 'close'}
# ...
